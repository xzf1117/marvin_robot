# %%
from lerobot.datasets import LeRobotDataset
from datasets import load_dataset

# %%
dataset = LeRobotDataset("zhifengxu/marvin_bimanual_v3")

# 打印数据集状态，看看 16维 state、action 和三路视频对不对
print(dataset)
print("视频/数据总帧数:", len(dataset))
# Out:
# LeRobotDataset({
#     Repository ID: 'zhifengxu/marvin_bimanual_v3',
#     Number of selected episodes: '1',
#     Number of selected samples: '146',
#     Features: '['observation.images.cam_head', 'observation.images.cam_left_wrist', 'observation.images.cam_right_wrist', 'observation.state', 'action', 'timestamp', 'frame_index', 'episode_index', 'index', 'task_index']',
# })
# 视频/数据总帧数: 146

# %%
first_frame = dataset[0]

# 3. 打印出各个核心特征，肉眼验证
print("=== 数据集物理读取验证 ===")
print("头部相机画面维度:", first_frame["observation.images.cam_head"].shape)       # 应该输出 torch.Size([3, 480, 640])
print("左腕相机画面维度:", first_frame["observation.images.cam_left_wrist"].shape) # 应该输出 torch.Size([3, 480, 640])
print("当前16维机械臂状态:", first_frame["observation.state"])
print("当前的语言任务指令:", first_frame["task"])
# Out:
# === 数据集物理读取验证 ===
# 头部相机画面维度: torch.Size([3, 480, 640])
# 左腕相机画面维度: torch.Size([3, 480, 640])
# 当前16维机械臂状态: tensor([ 1.5708e+00, -1.5708e+00, -1.5708e+00, -1.5708e+00, -5.7524e-06,
#          2.1572e-06,  4.0746e-06, -1.5708e+00, -1.5708e+00,  1.5708e+00,
#         -1.5708e+00,  1.3183e-06,  2.5167e-06,  1.0786e-06,  0.0000e+00,
#          1.8883e-02])
# 当前的语言任务指令: Pick up the block and place it into the container

# %%
parquet = load_dataset("parquet", data_files="/home/zju/.cache/huggingface/lerobot/zhifengxu/marvin_bimanual_v3/data/chunk-000/file-000.parquet")

# %%
print(parquet)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['observation.state', 'action', 'timestamp', 'frame_index', 'episode_index', 'index', 'task_index'],
#         num_rows: 146
#     })
# })

# %%
print(parquet['train'][0])
# Out:
# {'observation.state': [1.5708194971084595, -1.5707945823669434, -1.5707887411117554, -1.5707672834396362, -5.7524280236975756e-06, 2.1571606794168474e-06, 4.0746363083599135e-06, -1.5708087682724, -1.570794701576233, 1.5707967281341553, -1.5707833766937256, 1.3182647080611787e-06, 2.516687118259142e-06, 1.0785803397084237e-06, 0.0, 0.01888304017484188], 'action': [1.5708194971084595, -1.5707944631576538, -1.570788860321045, -1.5707674026489258, -5.63258572583436e-06, 2.277002749906387e-06, 4.194478606223129e-06, -1.5708084106445312, -1.570794939994812, 1.5707967281341553, -1.5707833766937256, 1.3182647080611787e-06, 2.277002749906387e-06, 1.1984225238848012e-06, 0.0, 0.01888304017484188], 'timestamp': 0.0, 'frame_index': 0, 'episode_index': 0, 'index': 0, 'task_index': 0}

# %%
tasks_parquet = load_dataset("parquet", data_files="/home/zju/.cache/huggingface/lerobot/zhifengxu/marvin_bimanual_v3/meta/tasks.parquet")
print(tasks_parquet)
infojson = load_dataset("json", data_files="/home/zju/.cache/huggingface/lerobot/zhifengxu/marvin_bimanual_v3/meta/info.json")
print(infojson)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['task_index', 'task'],
#         num_rows: 1
#     })
# })
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['codebase_version', 'fps', 'features', 'total_episodes', 'total_frames', 'total_tasks', 'chunks_size', 'data_files_size_in_mb', 'video_files_size_in_mb', 'data_path', 'video_path', 'robot_type', 'splits'],
#         num_rows: 1
#     })
# })
