# %%
from lerobot.datasets import LeRobotDataset
from datasets import load_dataset

# %%
dataset = LeRobotDataset("zhifengxu/marvin_pick_and_place_v1")

# 打印数据集状态，看看 16维 state、action 和三路视频对不对
print(dataset)
print("视频/数据总帧数:", len(dataset))
# Out:
# LeRobotDataset({
#     Repository ID: 'zhifengxu/marvin_pick_and_place_v1',
#     Number of selected episodes: '61',
#     Number of selected samples: '28407',
#     Features: '['observation.images.cam_head', 'observation.images.cam_left_wrist', 'observation.images.cam_right_wrist', 'observation.state', 'action', 'timestamp', 'frame_index', 'episode_index', 'index', 'task_index']',
# })
# 视频/数据总帧数: 28407

# %%
first_frame = dataset[0]
# 3. 打印出各个核心特征，肉眼验证
print("=== 数据集物理读取验证 ===")
print("头部相机画面维度:", first_frame["observation.images.cam_head"].shape)       # 应该输出 torch.Size([3, 480, 640])
print("左腕相机画面维度:", first_frame["observation.images.cam_left_wrist"].shape) # 应该输出 torch.Size([3, 480, 640])
print("当前16维机械臂状态:", first_frame["observation.state"])
# Out:
# === 数据集物理读取验证 ===
# 头部相机画面维度: torch.Size([3, 480, 640])
# 左腕相机画面维度: torch.Size([3, 480, 640])
# 当前16维机械臂状态: tensor([ 2.1023, -1.2983, -1.6003, -2.0930, -0.1705,  0.0826,  0.0512, -2.0948,
#         -1.2886,  1.5543, -2.0854,  0.1744,  0.0831, -0.1247, -2.0415, -0.0051])

# %%
parquet = load_dataset("parquet", data_files="/home/zju/.cache/huggingface/lerobot/zhifengxu/marvin_pick_and_place_v1/data/chunk-000/file-000.parquet")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
print(parquet)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['observation.state', 'action', 'timestamp', 'frame_index', 'episode_index', 'index', 'task_index'],
#         num_rows: 28407
#     })
# })

# %%
print(parquet['train'][0])
# Out:
# {'observation.state': [2.1023313999176025, -1.298283576965332, -1.6002525091171265, -2.093019962310791, -0.17049908638000488, 0.08255237340927124, 0.051198285073041916, -2.094834089279175, -1.2885640859603882, 1.5543389320373535, -2.0853655338287354, 0.1744338721036911, 0.08311288058757782, -0.12467632442712784, -2.041466474533081, -0.005149920005351305], 'action': [2.1023313999176025, -1.298283338546753, -1.6002525091171265, -2.093020439147949, -0.17049908638000488, 0.08255225419998169, 0.05119805037975311, -2.094834327697754, -1.2885639667510986, 1.554338812828064, -2.085365056991577, 0.1744338721036911, 0.08311251550912857, -0.12467657029628754, -2.041466474533081, -0.005149920005351305], 'timestamp': 0.0, 'frame_index': 0, 'episode_index': 0, 'index': 0, 'task_index': 0}

# %%
tasks_parquet = load_dataset("parquet", data_files="/home/zju/.cache/huggingface/lerobot/zhifengxu/marvin_pick_and_place_v1/meta/tasks.parquet")
print(tasks_parquet)
infojson = load_dataset("json", data_files="/home/zju/.cache/huggingface/lerobot/zhifengxu/marvin_pick_and_place_v1/meta/info.json")
print(infojson)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['task_index', 'task'],
#         num_rows: 1
#     })
# })
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['codebase_version', 'fps', 'features', 'total_episodes', 'total_frames', 'total_tasks', 'chunks_size', 'data_files_size_in_mb', 'video_files_size_in_mb', 'data_path', 'video_path', 'robot_type', 'splits'],
#         num_rows: 1
#     })
# })

# %%
dataset = LeRobotDataset("zhifengxu/marvin_pick_and_place_v3")

# 打印数据集状态，看看 16维 state、action 和三路视频对不对
print(dataset)
print("视频/数据总帧数:", len(dataset))
# Out:
# LeRobotDataset({
#     Repository ID: 'zhifengxu/marvin_pick_and_place_v3',
#     Number of selected episodes: '108',
#     Number of selected samples: '49270',
#     Features: '['observation.images.cam_head', 'observation.images.cam_left_wrist', 'observation.images.cam_right_wrist', 'observation.state', 'action', 'timestamp', 'frame_index', 'episode_index', 'index', 'task_index']',
# })
# 视频/数据总帧数: 49270
