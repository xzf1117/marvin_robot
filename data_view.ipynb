# %%
from lerobot.datasets import LeRobotDataset

# %%
dataset = LeRobotDataset("zhifengxu/marvin_bimanual_v3")

# 打印数据集状态，看看 16维 state、action 和三路视频对不对
print(dataset)
print("视频/数据总帧数:", len(dataset))
# Out:
# LeRobotDataset({
#     Repository ID: 'zhifengxu/marvin_bimanual_v3',
#     Number of selected episodes: '1',
#     Number of selected samples: '146',
#     Features: '['observation.images.cam_head', 'observation.images.cam_left_wrist', 'observation.images.cam_right_wrist', 'observation.state', 'action', 'timestamp', 'frame_index', 'episode_index', 'index', 'task_index']',
# })
# 视频/数据总帧数: 146

# %%
print("状态与动作特征均值/标准差:", dataset.meta.stats)
# Out:
# 状态与动作特征均值/标准差: {'observation.images.cam_head': {'min': array([[[0.        ]],
#
#        [[0.00392157]],
#
#        [[0.        ]]]), 'max': array([[[1.]],
#
#        [[1.]],
#
#        [[1.]]]), 'mean': array([[[0.23322715]],
#
#        [[0.24127753]],
#
#        [[0.23257735]]]), 'std': array([[[0.32447657]],
#
#        [[0.314971  ]],
#
#        [[0.3156566 ]]]), 'count': array([100]), 'q01': array([[[-3.92156868e-13]],
#
#        [[ 2.35929055e-02]],
#
#        [[ 7.93555650e-03]]]), 'q10': array([[[-3.92156868e-13]],
#
#        [[ 3.52541159e-02]],
#
#        [[ 2.34981114e-02]]]), 'q50': array([[[0.04716448]],
#
#        [[0.05885032]],
#
#        [[0.05493482]]]), 'q90': array([[[0.81972709]],
#
#        [[0.82357181]],
#
#        [[0.81563925]]]), 'q99': array([[[0.98039765]],
#
#        [[0.99986897]],
#
#        [[0.99605543]]])}, 'observation.images.cam_left_wrist': {'min': array([[[0.1254902 ]],
#
#        [[0.11764706]],
#
# ...
